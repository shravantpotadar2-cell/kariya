# %%
import pandas as pd

# %%
import numpy as np

demo1 = np.array([1, 2, 3, 4, 5])
demo2 = np.array([4, 3, 2, 1, 5])

res_map = np.array(list(map(lambda x, y: x + y, demo1, demo2)))

print("result of map using numpy", res_map)
# Out:
# result of map using numpy [ 5  5  5  5 10]

# %%
import numpy as np
from functools import reduce

demo1 = np.array([1, 2, 3, 4, 5])
demo2 = np.array([4, 3, 2, 1, 5])

res_reduce = reduce(lambda x, y: x + y, demo2)

print("result of reduce using numpy", res_reduce)
# Out:
# result of reduce using numpy 15

# %%
import numpy as np

demo1 = np.array([1, 2, 3, 4, 5])
demo2 = np.array([4, 3, 2, 1, 5])

def square(x):
    return x * x

vect_square = np.vectorize(square)
apply_square = vect_square(demo1)

print(apply_square)
# Out:
# [ 1  4  9 16 25]

# %%
import pandas as pd

data = {'A': [420, 380, 390], 'B': [50, 40, 45]}

df = pd.DataFrame(data)

df['A-mapped'] = df['A'].map(lambda x: x + 2)

print("mapped values", df['A-mapped'])
# Out:
# mapped values 0    422
# 1    382
# 2    392
# Name: A-mapped, dtype: int64

# %%
import pandas as pd

data = {'A': [420, 380, 390], 'B': [50, 40, 45]}

df = pd.DataFrame(data)

print(df)

df['Sum'] = df.apply(lambda row: row['A'] + row['B'], axis=1)

print("Sum of A & B using apply:", df['Sum'])
# Out:
#      A   B
# 0  420  50
# 1  380  40
# 2  390  45
# Sum of A & B using apply: 0    470
# 1    420
# 2    435
# Name: Sum, dtype: int64

# %%
import pandas as pd
from functools import reduce

data = {'a': [20, 30, 80, 90], 'b': [50, 40, 45, 60]}
df = pd.DataFrame(data)

print(df)

res_reduce = reduce(lambda x, y: x + y, df['b'])
print(res_reduce)
# Out:
#     a   b
# 0  20  50
# 1  30  40
# 2  80  45
# 3  90  60
# 195
